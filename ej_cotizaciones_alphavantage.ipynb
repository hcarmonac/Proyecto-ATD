# %%
import pandas as pd
import requests
import json

api_key = '0N8RXHW397V9ZYCL'
symbol = 'AAPL'
df = pd.DataFrame()

overview_params = {
    'function': 'OVERVIEW',
    'symbol': symbol,
    'apikey': api_key,
}

url = 'https://www.alphavantage.co/query'
response = requests.get(url, params=overview_params)

data = response.json()

print(f'The Market Cap of {data['Name']} is {data['MarketCapitalization']}.')
# Out:
# The Market Cap of Apple Inc is 4061369729000.
